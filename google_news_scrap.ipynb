# %%
# !python --version
# Out:
# Python 3.8.5

# %%
# developer : Seunghwan Lee

# %%
import requests
import datetime
import feedparser

class NewsScraper():
    def __init__(self):
        print ("News Scrapper initialize")
        print()
    def __del__(self): 
        self.stop()

    def exec(self, keyword, day, country = 'ko'):
        print ('Google News Cron Start: ' + datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S"))
        URL = 'https://news.google.com/rss/search?q={}+when:{}d'.format(keyword, day)
        if country == 'en':
            URL += '&hl=en-NG&gl=NG&ceid=NG:en'
        elif country == 'ko':
            URL += '&hl=ko&gl=KR&ceid=KR:ko'

        try: 
            res = requests.get(URL)
            if res.status_code == 200:
                datas = feedparser.parse(res.text).entries
                for data in datas:
#                     print(data)
                    print(data.title)
                    print(data.published)
                    print(data.link)
                    print()
            else:
                print ('Google Search Error!!')
        except requests.exceptions.RequestException as err:
            print ('Error Requests: {}'.format(err))

# %%
test = NewsScraper()

test.exec('스마트팩토리', '1')
# Out:
# Exception ignored in: <function NewsScraper.__del__ at 0x7fc0980391f0>
# Traceback (most recent call last):
#   File "<ipython-input-24-dd9d0aa77a3a>", line 10, in __del__
# AttributeError: 'NewsScraper' object has no attribute 'stop'
# News Scrapper initialize
#
# Google News Cron Start: 07/21/2021, 20:38:42
# 제일제강, 스마트팩토리 본격 구축…AI 솔루션 도입도 추진 - 한국경제
# Wed, 21 Jul 2021 01:48:03 GMT
# https://www.hankyung.com/finance/article/2021072168796
#
# 제일제강, 스마트팩토리 적용…“AI 솔루션으로 생산성 극대화” - 아시아경제
# Wed, 21 Jul 2021 00:55:00 GMT
# https://www.asiae.co.kr/article/2021072110270611440
#
# [SEN]제일제강, 스마트팩토리 시스템 도입…“AI 솔루션으로 생산성 극대화” - 서울경제 - 서울경제신문
# Wed, 21 Jul 2021 02:39:12 GMT
# https://sedaily.com/NewsView/22OZY6SXI5
#
# 스마트 팩토리 솔루션 시장 2021: 2027년까지 글로벌 산업 규모 및 성장 기회 – 시니어생활경제신문 - 시니어생활경제신문
# Wed, 21 Jul 2021 06:44:24 GMT
# https://lifenbiz.com/news/86172/%EC%8A%A4%EB%A7%88%ED%8A%B8-%ED%8C%A9%ED%86%A0%EB%A6%AC-%EC%86%94%EB%A3%A8%EC%85%98-%EC%8B%9C%EC%9E%A5-2021-2027%EB%85%84%EA%B9%8C%EC%A7%80-%EA%B8%80%EB%A1%9C%EB%B2%8C-%EC%82%B0%EC%97%85-%EA%B7%9C/
#
# 푸드테크 기업 설로인, 160억원 규모 투자 유치 - 매일경제
# Wed, 21 Jul 2021 04:47:16 GMT
# https://www.mk.co.kr/news/business/view/2021/07/701740/
#
# LGU+, 여수 석유화학단지에 5G MEC 기반 '스마트산단' 구축 - ITBizNews
# Wed, 21 Jul 2021 01:39:00 GMT
# https://www.itbiznews.com/news/articleView.html?idxno=43828
#
# LG유플러스, '지속가능경영 보고서' 발간 - ZD넷 코리아
# Wed, 21 Jul 2021 00:37:00 GMT
# https://zdnet.co.kr/view/?no=20210721093701
#
# 슈나이더가 알려주는 우리 공장에 맞는 공장 장비 디지털 솔루션은? - 헬로티
#
# 충남교육청, 마이스터고 4개교 대상 학점제 공동교육과정 운영 - 뉴스티앤티
# Tue, 20 Jul 2021 14:59:00 GMT
# http://www.newstnt.com/news/articleView.html?idxno=90588
#
# [대한민국 성장동력 ③] '뉴딜 2.0 신성장산업' 전문가 투자전망 - 서울와이어
# Wed, 21 Jul 2021 08:24:09 GMT
# https://www.seoulwire.com/news/articleView.html?idxno=447275
#
# '137조 원' 대 로봇 시장에 푹 빠진 CEO - 글로벌이코노믹
# Tue, 20 Jul 2021 22:00:00 GMT
# https://www.g-enews.com/view.php?ud=202107191500074377becd74a0af_1&ssk=2017011301560109486_1
#
# 브러시리스 DC 시장, 2027년까지 엄청난 성장 목격 | Nidec, HyUnion Holding, Maxon Motor – 시니어생활경제신문 - 시니어생활경제신문
# Wed, 21 Jul 2021 06:42:09 GMT
# https://lifenbiz.com/news/86235/%EB%B8%8C%EB%9F%AC%EC%8B%9C%EB%A6%AC%EC%8A%A4-dc-%EC%8B%9C%EC%9E%A5-2027%EB%85%84%EA%B9%8C%EC%A7%80-%EC%97%84%EC%B2%AD%EB%82%9C-%EC%84%B1%EC%9E%A5-%EB%AA%A9%EA%B2%A9-nidec-hyunion-holding-maxon-m/
#
# 화장품신문 (Beautynury.com) :: "벤처 투자업계 맞춤형 화장품 투자 본격화" - 뷰티누리(화장품신문)
# Tue, 20 Jul 2021 21:00:00 GMT
# https://www.beautynury.com/news/view/93964/cat/10/page/1
#
# [대구기계부품연구원 설립 20년 기념 지상좌담회]DMI, 기계소재부품분야 R&BD 허브 역할 기대 - 전자신문
# Wed, 21 Jul 2021 06:00:00 GMT
# https://www.etnews.com/20210721000051
#
# [유통가 레이더] hy, 유통기업 전환 급가속... 카카오와 IT플랫폼 구축 위해 협력 등 - 녹색경제신문
# Wed, 21 Jul 2021 05:47:58 GMT
# https://www.greened.kr/news/articleView.html?idxno=290752
#
# 미래차·디지털전환·헬스케어 15개사 사업재편 승인…1269억 투자·407명 채용 계획 - 뉴스핌
# Wed, 21 Jul 2021 02:00:00 GMT
# https://www.newspim.com/news/view/20210721000369
#
# [데일리픽] 우주로 간 제프 베조스, 실리콘밸리도 델타변이 확산 - 디지털투데이
# Wed, 21 Jul 2021 07:06:02 GMT
# https://www.digitaltoday.co.kr/news/articleView.html?idxno=410435

# %% [markdown]
# * http://newssearch.naver.com/search.naver?where=rss&query=%ED%86%A0%EC%8A%A4%EB%9E%A9&field=0&nx_search_query=&nx_and_query=&nx_sub_query=&nx_search_hlquery=&is_dts=0%22,%22%22,true,100)
# * 이상 네이터 뉴스 RSS 피드
#
# * goose3 를 이용한 예제
#  https://junpyopark.github.io/rss_parse/
#
# * sqlite 를 이용한 예제
#  https://brunch.co.kr/@moaikim/38
#
# * pandas 를 이용한 엑셀 정리 예제
#  https://m.blog.naver.com/pmw9440/221849471131
#
# * news rss 정리
#  https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=mindisit&logNo=220402908308
#
# * rss 링크 정리를 위한 pickle 예제
#  https://korbillgates.tistory.com/173
